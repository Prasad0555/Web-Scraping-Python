# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
response = requests.get('https://rmn-api.rojgarmantra.com:8087/api/address/getAllCountry',verify = False).text
# Out:
# C:\Users\om soft\anaconda3\lib\site-packages\urllib3\connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'rmn-api.rojgarmantra.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
response
# Out:
# '{"response":[{"countryId":1,"csvId":1,"shortName":"AF","countryName":"Afghanistan","phoneCode":"93","vatPercentage":3.0,"icon":"https://intrecjvm.s3.ap-south-1.amazonaws.com/country_1624516277036.jpg"},{"countryId":2,"csvId":2,"shortName":"AL","countryName":"Albania","phoneCode":"355","vatPercentage":0.0,"icon":null},{"countryId":3,"csvId":3,"shortName":"DZ","countryName":"Algeria","phoneCode":"213","vatPercentage":0.0,"icon":null},{"countryId":4,"csvId":4,"shortName":"AS","countryName":"American Samoa","phoneCode":"1684","vatPercentage":0.0,"icon":null},{"countryId":5,"csvId":5,"shortName":"AD","countryName":"Andorra","phoneCode":"376","vatPercentage":1.0,"icon":null},{"countryId":6,"csvId":6,"shortName":"AO","countryName":"Angola","phoneCode":"244","vatPercentage":0.0,"icon":null},{"countryId":7,"csvId":7,"shortName":"AI","countryName":"Anguilla","phoneCode":"1264","vatPercentage":0.0,"icon":null},{"countryId":8,"csvId":8,"shortName":"AQ","countryName":"Antarctica","phoneCode":"0"
# ...

# %%
import json

# %%
raw_data = json.loads(response)

# %%
raw_data
# Out:
# {'response': [{'countryId': 1,
#    'csvId': 1,
#    'shortName': 'AF',
#    'countryName': 'Afghanistan',
#    'phoneCode': '93',
#    'vatPercentage': 3.0,
#    'icon': 'https://intrecjvm.s3.ap-south-1.amazonaws.com/country_1624516277036.jpg'},
#   {'countryId': 2,
#    'csvId': 2,
#    'shortName': 'AL',
#    'countryName': 'Albania',
#    'phoneCode': '355',
#    'vatPercentage': 0.0,
#    'icon': None},
#   {'countryId': 3,
#    'csvId': 3,
#    'shortName': 'DZ',
#    'countryName': 'Algeria',
#    'phoneCode': '213',
#    'vatPercentage': 0.0,
#    'icon': None},
#   {'countryId': 4,
#    'csvId': 4,
#    'shortName': 'AS',
#    'countryName': 'American Samoa',
#    'phoneCode': '1684',
#    'vatPercentage': 0.0,
#    'icon': None},
#   {'countryId': 5,
#    'csvId': 5,
#    'shortName': 'AD',
#    'countryName': 'Andorra',
#    'phoneCode': '376',
#    'vatPercentage': 1.0,
#    'icon': None},
#   {'countryId': 6,
#    'csvId': 6,
#    'shortName': 'AO',
# ...

# %%
data = raw_data['response']

# %%
data
# Out:
# [{'countryId': 1,
#   'csvId': 1,
#   'shortName': 'AF',
#   'countryName': 'Afghanistan',
#   'phoneCode': '93',
#   'vatPercentage': 3.0,
#   'icon': 'https://intrecjvm.s3.ap-south-1.amazonaws.com/country_1624516277036.jpg'},
#  {'countryId': 2,
#   'csvId': 2,
#   'shortName': 'AL',
#   'countryName': 'Albania',
#   'phoneCode': '355',
#   'vatPercentage': 0.0,
#   'icon': None},
#  {'countryId': 3,
#   'csvId': 3,
#   'shortName': 'DZ',
#   'countryName': 'Algeria',
#   'phoneCode': '213',
#   'vatPercentage': 0.0,
#   'icon': None},
#  {'countryId': 4,
#   'csvId': 4,
#   'shortName': 'AS',
#   'countryName': 'American Samoa',
#   'phoneCode': '1684',
#   'vatPercentage': 0.0,
#   'icon': None},
#  {'countryId': 5,
#   'csvId': 5,
#   'shortName': 'AD',
#   'countryName': 'Andorra',
#   'phoneCode': '376',
#   'vatPercentage': 1.0,
#   'icon': None},
#  {'countryId': 6,
#   'csvId': 6,
#   'shortName': 'AO',
#   'countryName': 'Angola',
#   'phoneCode': '244',
# ...

# %%
type(data)
# Out:
# list

# %%
dataframe = pd.DataFrame.from_dict(data)
dataframe
# Out:
#      countryId  csvId shortName     countryName phoneCode  vatPercentage  \
# 0            1    1.0        AF     Afghanistan        93            3.0
# 1            2    2.0        AL         Albania       355            0.0
# 2            3    3.0        DZ         Algeria       213            0.0
# 3            4    4.0        AS  American Samoa      1684            0.0
# 4            5    5.0        AD         Andorra       376            1.0
# ..         ...    ...       ...             ...       ...            ...
# 248        242  242.0        EH  Western Sahara       212            0.0
# 249        243  243.0        YE           Yemen       967            0.0
# 250        244  244.0        YU      Yugoslavia        38            0.0
# 251        245  245.0        ZM          Zambia       260            0.0
# 252        246  246.0        ZW        Zimbabwe       263            0.0
#
#                                                   icon
# ...

# %%
# saving the dataframe
dataframe.to_csv('MyCSV')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_984/3774137984.py in <module>
#       1 # saving the dataframe
# ----> 2 df.to_csv('Mobile Apps Developers')
#
# NameError: name 'df' is not defined
